# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
rmse_10 = np.load('10k_rmse.npy')
r#mse_100 = np.load('100k_rmse.npy')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 rmse_10 = np.load('10k_rmse.npy')
# ----> 2 r#mse_100 = np.load('100k_rmse.npy')
#
# NameError: name 'r' is not defined

# %%
plt.figure(figsize=(8, 5))
plt.hist(rmse_10, bins=20, color='skyblue', edgecolor='black', alpha=0.7)
plt.xlabel('RMSE')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.title('10K')
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.hist(rmse_100, bins=20, color='crimson', edgecolor='black', alpha=0.7)
plt.xlabel('RMSE')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.title('100K')
plt.show()
