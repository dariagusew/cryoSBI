# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
rmse_10 = np.load('10k_rmse.npy')
#rmse_100 = np.load('100k_rmse.npy')

# %%
plt.figure(figsize=(8, 5))
plt.hist(rmse_10, bins=20, color='skyblue', edgecolor='black', alpha=0.7)
plt.xlabel('RMSE')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.title('10K')
plt.show()

# %%
np.std(rmse_10)
# Out:
# np.float64(0.025904930028422493)

# %%
plt.figure(figsize=(8, 5))
plt.hist(rmse_100, bins=20, color='crimson', edgecolor='black', alpha=0.7)
plt.xlabel('RMSE')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.title('100K')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 plt.figure(figsize=(8, 5))
# ----> 2 plt.hist(rmse_100, bins=20, color='crimson', edgecolor='black', alpha=0.7)
#       3 plt.xlabel('RMSE')
#       4 plt.ylabel('Frequency')
#
# NameError: name 'rmse_100' is not defined
